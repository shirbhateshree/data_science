# %%
import pandas as pd
from sklearn import preprocessing
df = pd.read_csv("D:\ETL\python_training\scikit-learn\WA_Fn-UseC_-Sales-Win-Loss.csv")
le = preprocessing.LabelEncoder()
df.head
# Out:
# <bound method NDFrame.head of        Opportunity Number        Supplies Subgroup          Supplies Group  \
# 0                 1641984     Exterior Accessories         Car Accessories
# 1                 1658010     Exterior Accessories         Car Accessories
# 2                 1674737         Motorcycle Parts  Performance & Non-auto
# 3                 1675224            Shelters & RV  Performance & Non-auto
# 4                 1689785     Exterior Accessories         Car Accessories
# ...                   ...                      ...                     ...
# 78020            10089932  Batteries & Accessories         Car Accessories
# 78021            10089961            Shelters & RV  Performance & Non-auto
# 78022            10090145     Exterior Accessories         Car Accessories
# 78023            10090430     Exterior Accessories         Car Accessories
# 78024            10094255     Interior Accessories         Car Accessories
#
# ...

# %%
df['Supplies Subgroup'] = le.fit_trasform(df['Supplies Subgroup'])
df['Region'] = le.fit_trasform(df['Region'])
df['Route To Market'] = le.fit_trasform(df['Route To Market'])
df['Opportunity Result'] = le.fit_trasform(df['opportunity Result'])
df['Competitor Type'] = le.fit_trasform(df['Competitor Type'])
df['Supplies Group'] = le.fit_trasform(df['Supplies Group'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-75ad5dfad268> in <module>
# ----> 1 df['Supplies Subgroup'] = le.fit_trasform(df['Supplies Subgroup'])
#       2 df['Region'] = le.fit_trasform(df['Region'])
#       3 df['Route To Market'] = le.fit_trasform(df['Route To Market'])
#       4 df['Opportunity Result'] = le.fit_trasform(df['opportunity Result'])
#       5 df['Competitor Type'] = le.fit_trasform(df['Competitor Type'])
#
# NameError: name 'le' is not defined

# %%
df(drop.na)

# %%
import pandas as pd
from sklearn import preprocessing
df = pd.read_csv("D:\ETL\python_training\scikit-learn\WA_Fn-UseC_-Sales-Win-Loss.csv")
le = preprocessing.LabelEncoder()
df.head()
# Out:
#    Opportunity Number     Supplies Subgroup          Supplies Group  \
# 0             1641984  Exterior Accessories         Car Accessories
# 1             1658010  Exterior Accessories         Car Accessories
# 2             1674737      Motorcycle Parts  Performance & Non-auto
# 3             1675224         Shelters & RV  Performance & Non-auto
# 4             1689785  Exterior Accessories         Car Accessories
#
#       Region Route To Market  Elapsed Days In Sales Stage Opportunity Result  \
# 0  Northwest    Fields Sales                           76                Won
# 1    Pacific        Reseller                           63               Loss
# 2    Pacific        Reseller                           24                Won
# 3    Midwest        Reseller                           16               Loss
# 4    Pacific        Reseller                           69               Loss
#
#    Sales Stage Change Count  Total Days Identified Through Closing  \
# 0                        13                                    104
# 1                         2                                    163
# 2                         7                                     82
# 3                         5                                    124
# 4                        11                                     91
#
#    Total Days Identified Through Qualified  Opportunity Amount USD  \
# 0                                      101                       0
# 1                                      163                       0
# 2                                       82                    7750
# 3                                      124                       0
# 4                                       13                   69756
#
#    Client Size By Revenue  Client Size By Employee Count  \
# 0                       5                              5
# 1                       3                              5
# 2                       1                              1
# 3                       1                              1
# 4                       1                              1
#
#    Revenue From Client Past Two Years Competitor Type  \
# 0                                   0         Unknown
# 1                                   0         Unknown
# 2                                   0         Unknown
# 3                                   0           Known
# 4                                   0         Unknown
#
#    Ratio Days Identified To Total Days  Ratio Days Validated To Total Days  \
# 0                              0.69636                            0.113985
# 1                              0.00000                            1.000000
# 2                              1.00000                            0.000000
# 3                              1.00000                            0.000000
# 4                              0.00000                            0.141125
#
#    Ratio Days Qualified To Total Days  Deal Size Category
# 0                            0.154215                   1
# 1                            0.000000                   1
# 2                            0.000000                   1
# 3                            0.000000                   1
# 4                            0.000000                   4

# %%
df.head()
# Out:
#    Opportunity Number     Supplies Subgroup          Supplies Group  \
# 0             1641984  Exterior Accessories         Car Accessories
# 1             1658010  Exterior Accessories         Car Accessories
# 2             1674737      Motorcycle Parts  Performance & Non-auto
# 3             1675224         Shelters & RV  Performance & Non-auto
# 4             1689785  Exterior Accessories         Car Accessories
#
#       Region Route To Market  Elapsed Days In Sales Stage Opportunity Result  \
# 0  Northwest    Fields Sales                           76                Won
# 1    Pacific        Reseller                           63               Loss
# 2    Pacific        Reseller                           24                Won
# 3    Midwest        Reseller                           16               Loss
# 4    Pacific        Reseller                           69               Loss
#
#    Sales Stage Change Count  Total Days Identified Through Closing  \
# 0                        13                                    104
# 1                         2                                    163
# 2                         7                                     82
# 3                         5                                    124
# 4                        11                                     91
#
#    Total Days Identified Through Qualified  Opportunity Amount USD  \
# 0                                      101                       0
# 1                                      163                       0
# 2                                       82                    7750
# 3                                      124                       0
# 4                                       13                   69756
#
#    Client Size By Revenue  Client Size By Employee Count  \
# 0                       5                              5
# 1                       3                              5
# 2                       1                              1
# 3                       1                              1
# 4                       1                              1
#
#    Revenue From Client Past Two Years Competitor Type  \
# 0                                   0         Unknown
# 1                                   0         Unknown
# 2                                   0         Unknown
# 3                                   0           Known
# 4                                   0         Unknown
#
#    Ratio Days Identified To Total Days  Ratio Days Validated To Total Days  \
# 0                              0.69636                            0.113985
# 1                              0.00000                            1.000000
# 2                              1.00000                            0.000000
# 3                              1.00000                            0.000000
# 4                              0.00000                            0.141125
#
#    Ratio Days Qualified To Total Days  Deal Size Category
# 0                            0.154215                   1
# 1                            0.000000                   1
# 2                            0.000000                   1
# 3                            0.000000                   1
# 4                            0.000000                   4

# %%
df['Supplies Subgroup']=le.fit_transform(df['Supplies Subgroup'])
df['Region'] = le.fit_transform(df['Region'])
df['Route To Market'] = le.fit_transform(df['Route To Market'])
df['Opportunity Result'] = le.fit_transform(df['Opportunity Result'])
df['Competitor Type'] = le.fit_transform(df['Competitor Type'])
df['Supplies Group'] = le.fit_transform(df['Supplies Group'])

# %%
feature_cols = [col for col in df.columns if col not in ['Opportunity Number','opportunity Result']]
target = df['Opportunity Result']
data = df[feature_cols]
data.head()
# Out:
#    Supplies Subgroup  Supplies Group  Region  Route To Market  \
# 0                  2               0       3                0
# 1                  2               0       4                2
# 2                  5               2       4                2
# 3                  8               2       1                2
# 4                  2               0       4                2
#
#    Elapsed Days In Sales Stage  Opportunity Result  Sales Stage Change Count  \
# 0                           76                   1                        13
# 1                           63                   0                         2
# 2                           24                   1                         7
# 3                           16                   0                         5
# 4                           69                   0                        11
#
#    Total Days Identified Through Closing  \
# 0                                    104
# 1                                    163
# 2                                     82
# 3                                    124
# 4                                     91
#
#    Total Days Identified Through Qualified  Opportunity Amount USD  \
# 0                                      101                       0
# 1                                      163                       0
# 2                                       82                    7750
# 3                                      124                       0
# 4                                       13                   69756
#
#    Client Size By Revenue  Client Size By Employee Count  \
# 0                       5                              5
# 1                       3                              5
# 2                       1                              1
# 3                       1                              1
# 4                       1                              1
#
#    Revenue From Client Past Two Years  Competitor Type  \
# 0                                   0                2
# 1                                   0                2
# 2                                   0                2
# 3                                   0                0
# 4                                   0                2
#
#    Ratio Days Identified To Total Days  Ratio Days Validated To Total Days  \
# 0                              0.69636                            0.113985
# 1                              0.00000                            1.000000
# 2                              1.00000                            0.000000
# 3                              1.00000                            0.000000
# 4                              0.00000                            0.141125
#
#    Ratio Days Qualified To Total Days  Deal Size Category
# 0                            0.154215                   1
# 1                            0.000000                   1
# 2                            0.000000                   1
# 3                            0.000000                   1
# 4                            0.000000                   4

# %%
from sklearn.model_selection import GaussianNB
from sklearn.metrics import accuracy_score
gnb = GaussianNB()
pred = gnb.fit(x_train,y_train).predict(x_test)
print(pred)
accuracy_score(y-test,pred,normalize = True)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-43-1d4fffb01b66> in <module>
# ----> 1 from sklearn.model_selection import GaussianNB
#       2 from sklearn.metrics import accuracy_score
#       3 gnb = GaussianNB()
#       4 pred = gnb.fit(x_train,y_train).predict(x_test)
#       5 print(pred)
#
# ImportError: cannot import name 'GaussianNB' from 'sklearn.model_selection' (d:\etl\env\lib\site-packages\sklearn\model_selection\__init__.py)

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(data, target, test_size = 0.30,random_state = 10)
print(x_train)
print(y_test)
# Out:
#        Supplies Subgroup  Supplies Group  Region  Route To Market  \
# 58546                  6               2       0                0
# 38963                  5               2       4                2
# 56239                  4               0       6                0
# 18336                  5               2       4                0
# 73136                  3               0       6                0
# ...                  ...             ...     ...              ...
# 17904                  4               0       4                3
# 37597                  6               2       3                0
# 10201                  5               2       4                0
# 9372                   0               0       1                1
# 50496                  5               2       6                2
#
#        Elapsed Days In Sales Stage  Opportunity Result  \
# 58546                           49                   0
# 38963                           25                   1
# 56239                           67                   0
# 18336                           63                   0
# 73136                           23                   0
# ...                            ...                 ...
# 17904                           63                   0
# 37597                           19                   1
# 10201                           83                   0
# 9372                            42                   1
# 50496                           42                   1
#
#        Sales Stage Change Count  Total Days Identified Through Closing  \
# 58546                         2                                     24
# 38963                         3                                      3
# 56239                         4                                     14
# 18336                         2                                     11
# 73136                         2                                      0
# ...                         ...                                    ...
# 17904                         2                                     12
# 37597                         5                                     12
# 10201                         2                                      8
# 9372                          3                                      3
# 50496                         4                                      7
#
#        Total Days Identified Through Qualified  Opportunity Amount USD  \
# 58546                                       24                   10000
# 38963                                        3                    2142
# 56239                                       14                    5000
# 18336                                       11                   20000
# 73136                                        0                  500000
# ...                                        ...                     ...
# 17904                                       12                   50000
# 37597                                       11                  133000
# 10201                                        8                    5000
# 9372                                         3                      18
# 50496                                        7                  384000
#
#        Client Size By Revenue  Client Size By Employee Count  \
# 58546                       2                              1
# 38963                       1                              1
# 56239                       4                              5
# 18336                       3                              5
# 73136                       1                              1
# ...                       ...                            ...
# 17904                       1                              3
# 37597                       1                              1
# 10201                       4                              2
# 9372                        4                              3
# 50496                       1                              1
#
#        Revenue From Client Past Two Years  Competitor Type  \
# 58546                                   0                2
# 38963                                   0                1
# 56239                                   0                2
# 18336                                   0                2
# 73136                                   0                2
# ...                                   ...              ...
# 17904                                   0                2
# 37597                                   0                2
# 10201                                   0                0
# 9372                                    0                1
# 50496                                   0                2
#
#        Ratio Days Identified To Total Days  \
# 58546                             1.000000
# 38963                             0.000000
# 56239                             0.285714
# 18336                             0.000000
# 73136                             0.000000
# ...                                    ...
# 17904                             1.000000
# 37597                             0.026087
# 10201                             1.000000
# 9372                              0.000000
# 50496                             0.202899
#
#        Ratio Days Validated To Total Days  Ratio Days Qualified To Total Days  \
# 58546                            0.000000                            0.000000
# 38963                            1.000000                            0.000000
# 56239                            0.142857                            0.571429
# 18336                            1.000000                            0.000000
# 73136                            0.000000                            0.000000
# ...                                   ...                                 ...
# 17904                            0.000000                            0.000000
# 37597                            0.008696                            0.939130
# 10201                            0.000000                            0.000000
# 9372                             1.000000                            0.000000
# 50496                            0.797101                            0.000000
#
#        Deal Size Category
# 58546                   2
# 38963                   1
# 56239                   1
# 18336                   2
# 73136                   7
# ...                   ...
# 17904                   4
# 37597                   5
# 10201                   1
# 9372                    1
# 50496                   6
#
# [54617 rows x 18 columns]
# 66103    0
# 50020    0
# 74422    0
# 25496    1
# 53272    1
#         ..
# 65650    0
# 25662    0
# 36087    0
# 28442    0
# 21445    0
# Name: Opportunity Result, Length: 23408, dtype: int32

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score
gnb = GaussianNB()
pred = gnb.fit(x_train,y_train).predict(x_test)
print(pred)
accuracy_score(y_test,pred,normalize = True)
# Out:
# [0 0 0 ... 0 0 1]
# 0.7745215311004785

# %%
from sklearn.svm import LinearSVC
from sklearn.metrics import acccuracy_score
svc_model = LinearSVC(random_state=1,max_iter = 100)
pred = svc_model.fit(x_train,y_train).predict(x_test)
print(pred)
accuracy_score(y_test,pred,normalize = True)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-51-fe8aa5f43711> in <module>
#       1 from sklearn.svm import LinearSVC
# ----> 2 from sklearn.metrics import acccuracy_score
#       3 svc_model = LinearSVC(random_state=1,max_iter=100)
#       4 pred = svc_model.fit(x_train,y_train).predict(x_test)
#       5 print(pred)
#
# ImportError: cannot import name 'acccuracy_score' from 'sklearn.metrics' (d:\etl\env\lib\site-packages\sklearn\metrics\__init__.py)

# %%
from sklearn.neighbors  import KNeighborsClassifier
from sklearn.metrics import acccuracy_score
neigh = KNeighborsClassifier(n_neighbors=3)
neigh.fit(x_train,y_train)
pred = neigh.predict(x_test)
accuracy_score(y-test,pred,normalize = True)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-59-e2d5d846cf52> in <module>
#       1 from sklearn.neighbors  import KNeighborsClassifier
# ----> 2 from sklearn.metrics import acccuracy_score
#       3 neigh = KNeighborsClassifier(n_neighbors=3)
#       4 neigh.fit(x_train,y_train)
#       5 pred = neigh.predict(x_test)
#
# ImportError: cannot import name 'acccuracy_score' from 'sklearn.metrics' (d:\etl\env\lib\site-packages\sklearn\metrics\__init__.py)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import acccuracy_score
import matplotlib.pyplot as plt
import numpy as np

x_train, x_test, y_train, y_test = train_test_split(data, target, test_size=0.30, random_state = 10)
reg = LinearRegression()
reg.fit(x_train, y_train)
pred = reg.predict(x_test)
print("pred===",pred)
print("reg.coef_==",reg.intercept_)
print("reg.intercept_==",reg.intercept_)
print("len(x_test)==",len(x_test))
print("y_test==",len(y_test))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-62-33267f90f75c> in <module>
#       1 from sklearn.linear_model import LinearRegression
# ----> 2 from sklearn.metrics import acccuracy_score
#       3 import matplotlib.pyplot as plt
#       4 import numpy as np
#       5
#
# ImportError: cannot import name 'acccuracy_score' from 'sklearn.metrics' (d:\etl\env\lib\site-packages\sklearn\metrics\__init__.py)
